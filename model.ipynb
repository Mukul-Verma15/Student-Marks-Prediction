# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder , MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#           Name  Gender   Age   Math  Science  English  Attendance  StudyHours  \
# 0      Olivia0  Female  21.0   26.0     29.0     88.0        56.0         6.0
# 1       Allen1    Male  16.0   31.0     75.0     73.0        54.0         4.0
# 2      Sophia2    Male  17.0  100.0    100.0     94.0        53.0        10.0
# 3        Noah3    Male  16.0   91.0     37.0     57.0        76.0         NaN
# 4        John4    Male  16.0   94.0     93.0     44.0        73.0         2.0
# ..         ...     ...   ...    ...      ...      ...         ...         ...
# 995  Sophia995  Female  21.0   82.0     72.0     62.0        68.0         4.0
# 996     Mia996  Female  19.0   30.0     57.0     34.0        80.0         3.0
# 997    Emma997  Female  17.0   49.0     51.0     43.0        79.0         3.0
# 998   David998    Male  21.0   83.0      NaN     97.0        98.0         9.0
# 999    John999  Female  18.0   34.0     29.0     31.0       400.0         2.0
#
#      PreviousMarks  Target
# ...

# %%
test
# Out:
#           Name  Gender   Age   Math  Science  English  Attendance  StudyHours  \
# 0         Mia0  Female  16.0   41.0     48.0     98.0        57.0         9.0
# 1      Sophia1  Female  22.0   82.0     25.0     47.0        80.0         2.0
# 2        John2    Male   NaN   94.0     79.0     48.0       -30.0         8.0
# 3        Noah3    Male  21.0  250.0     93.0     57.0        79.0         1.0
# 4      Olivia4    Male  18.0   83.0     27.0     35.0        59.0         6.0
# ..         ...     ...   ...    ...      ...      ...         ...         ...
# 195    Emma195    Male  18.0   21.0     26.0     92.0        89.0         8.0
# 196  Sophia196    Male  19.0   62.0     22.0     40.0        85.0         6.0
# 197    John197  Female  18.0    NaN      NaN     92.0        62.0         7.0
# 198    Liam198  Female  22.0   62.0     87.0     88.0        69.0         NaN
# 199     Mia199    Male  19.0  -30.0     98.0     71.0        95.0         8.0
#
#      PreviousMarks
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1000 non-null   object
#  1   Gender         980 non-null    object
#  2   Age            950 non-null    float64
#  3   Math           950 non-null    float64
#  4   Science        951 non-null    float64
#  5   English        950 non-null    float64
#  6   Attendance     951 non-null    float64
#  7   StudyHours     950 non-null    float64
#  8   PreviousMarks  950 non-null    float64
#  9   Target         1000 non-null   int64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 78.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           200 non-null    object
#  1   Gender         198 non-null    object
#  2   Age            190 non-null    float64
#  3   Math           190 non-null    float64
#  4   Science        191 non-null    float64
#  5   English        190 non-null    float64
#  6   Attendance     190 non-null    float64
#  7   StudyHours     190 non-null    float64
#  8   PreviousMarks  190 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 14.2+ KB

# %%
train.isna().sum()
# Out:
# Name              0
# Gender           20
# Age              50
# Math             50
# Science          49
# English          50
# Attendance       49
# StudyHours       50
# PreviousMarks    50
# Target            0
# dtype: int64

# %%
col = ['Age','Math','Science','English','Attendance','StudyHours','PreviousMarks']

train[col] = train[col].fillna(train[col].mean())
train['Gender'] = train['Gender'].fillna(train['Gender'].mode()[0])

# %%
train['Gender'].value_counts()
# Out:
# Gender
# Female    514
# Male      486
# Name: count, dtype: int64

# %%
test.isna().sum()
# Out:
# Name              0
# Gender            2
# Age              10
# Math             10
# Science           9
# English          10
# Attendance       10
# StudyHours       10
# PreviousMarks    10
# dtype: int64

# %%
col = ['Age','Math','Science','English','Attendance','StudyHours','PreviousMarks']

test[col] = test[col].fillna(test[col].mean())
test['Gender'] = test['Gender'].fillna(test['Gender'].mode()[0])

# %%
le = LabelEncoder()
mm = MinMaxScaler()
for i in train.columns:
    if train[i].dtype == 'object':
        train[i]=le.fit_transform(train[i])

for i in test.columns:
    if test[i].dtype == 'object':
        test[i]=le.fit_transform(test[i])

# %%
train.iloc[:,:-1]=mm.fit_transform(train.iloc[:,:-1])
test.iloc[:,:]=mm.transform(test.iloc[:,:])
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_9304\3216951432.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.67367367 0.         0.91491491 0.58458458 0.32132132 0.33333333
#  0.73573574 0.74374374 0.26026026 0.77577578 0.08508509 0.49449449
#  0.2962963  0.67967968 0.003003   0.4994995  0.57057057 0.18018018
#  0.5045045  0.41241241 0.68668669 0.18618619 0.68768769 0.7987988
#  0.68968969 0.42142142 0.69169169 0.19319319 0.1951952  0.6986987
#  0.8048048  0.7017017  0.58958959 0.51951952 0.02102102 0.02202202
#  0.52352352 0.11811812 0.70970971 0.71171171 0.20720721 0.03003003
#  0.93693694 0.21021021 0.53053053 0.03403403 0.03603604 0.21721722
#  0.45245245 0.94494494 0.94794795 0.61361361 0.22122122 0.04204204
#  0.72572573 0.45745746 0.62162162 0.95495495 0.13313313 0.95595596
#  0.73673674 0.95895896 0.34934935 0.85685686 0.54254254 0.54454454
# ...

# %%
X = train.iloc[:,:-1]
Y = train['Target']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X,Y)
model
# Out:
# LinearRegression()

# %%
X_test = test

predictions = model.predict(X_test)

print(predictions)
# Out:
# Fold Accuracies: [0.88  0.905 0.885 0.83  0.905]
# Average Accuracy: 0.881
